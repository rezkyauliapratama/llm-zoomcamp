# %% [markdown]
# # Final Project — Exploration Notebook
# OJK Regulatory Q&A: data exploration, chunking experiments, retrieval prototyping.

# %%
# Install dependencies
# !pip install -r ../requirements.txt
