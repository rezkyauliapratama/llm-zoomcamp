# %% [markdown]
# # Retrieval Evaluation
# ## Notebook 02: Hit Rate@K and MRR Across Retrieval Approaches
#
# Compares: Keyword-only vs Vector-only vs Hybrid RRF vs Hybrid+Reranker

# %%
# TODO: Load eval_questions.csv
# TODO: Run each retrieval approach
# TODO: Calculate Hit Rate@5 and MRR
# TODO: Visualize comparison table
